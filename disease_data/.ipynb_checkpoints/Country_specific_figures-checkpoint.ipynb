# %% [markdown]
# *Cleaned .xls file manually to remove columns/rows not able to be parsed by pandas.*
# *Also removed ailments clearly not caused by food like injuries, exposure to mechanical forces, natural disasters, other unintentional injuries, intentional injuries, self-harm, interpersonal violence, collective violence and legal intervention, drowning, falls, road injury, unintentional injuries, injuries, rabies, yellow fever, dengue and other vector diseases, SIDS,
# .*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

disease_df = pd.read_excel("cleanedGHE2016_DALYs-2016-country.xlsx", encoding='latin-1')
columns = disease_df.iloc[:,0].tolist()
del disease_df['GHE cause']
country_df = disease_df.transpose()
country_df.columns = columns
country_df.columns = [c.replace(' ', '_') for c in country_df.columns]

# %%
#Caribbean Countries
Caribbean_countries = country_df.loc[["Cuba", "Haiti", "Dominican Republic", "Jamaica", "Trinidad and Tobago", "Bahamas", "Barbados", "Saint Lucia", "Saint Vincent and the Grenadines", "Grenada", "Antigua and Barbuda"]]

#need to sum each column and make it the column for combined dataframe for Carribean
Caribbean_countries.loc['Caribbean'] = pd.Series(Caribbean_countries.sum())
Caribbean_countries

Caribbean = Caribbean_countries.loc[["Caribbean"]].sort_values(by='Caribbean', axis=1, ascending=False)
Caribbean = Caribbean.iloc[:, : 20]
Caribbean = Caribbean.drop(columns=['Population_thousands', 'All_Causes'])
#number affected by each disease

fig = plt.figure(figsize=(20,4))
plt.xlabel('Disease')
plt.ylabel('Number Affected (thousands)')
plt.title('Number Caribbeans Affected by Diseases')
plt.xticks(rotation='vertical')
plt.bar(Caribbean.columns, Caribbean.values[0], color='aquamarine')
fig.savefig('NumberCaribbeanssAffectedByDiseases.png', bbox_inches='tight')

# %%
#China
China = country_df.loc[["China"]].sort_values(by='China', axis=1, ascending=False)
China = China.iloc[:, : 20]
China = China.drop(columns=['Population_thousands', 'All_Causes'])
#number affected by each disease

fig = plt.figure(figsize=(20,4))
plt.xlabel('Disease')
plt.ylabel('Number Affected (thousands)')
plt.title('Number Chinese Affected by Diseases')
plt.xticks(rotation='vertical')
plt.bar(China.columns, China.values[0], color='aquamarine')
fig.savefig('NumberChineseAffectedByDiseases.png', bbox_inches='tight')

# %%
#France
France = country_df.loc[["France"]].sort_values(by='France', axis=1, ascending=False)
France = France.iloc[:, : 20]
France = France.drop(columns=['Population_thousands', 'All_Causes'])
#number affected by each disease

fig = plt.figure(figsize=(20,4))
plt.xlabel('Disease')
plt.ylabel('Number Affected (thousands)')
plt.title('Number French Affected by Diseases')
plt.xticks(rotation='vertical')
plt.bar(France.columns, France.values[0], color='aquamarine')
fig.savefig('NumberFrenchAffectedByDiseases.png', bbox_inches='tight')

# %%
#Greece
Greece = country_df.loc[["Greece"]].sort_values(by='Greece', axis=1, ascending=False)
Greece = Greece.iloc[:, : 20]
Greece = Greece.drop(columns=['Population_thousands', 'All_Causes'])
#number affected by each disease

fig = plt.figure(figsize=(20,4))
plt.xlabel('Disease')
plt.ylabel('Number Affected (thousands)')
plt.title('Number Greek Affected by Diseases')
plt.xticks(rotation='vertical')
plt.bar(Greece.columns, Greece.values[0], color='aquamarine')
fig.savefig('NumberGreekAffectedByDiseases.png', bbox_inches='tight')

# %%
#India
India = country_df.loc[["India"]].sort_values(by='India', axis=1, ascending=False)
India = India.iloc[:, : 20]
India = India.drop(columns=['Population_thousands', 'All_Causes'])
#number affected by each disease
fig = plt.figure(figsize=(20,4))
plt.xlabel('Disease')
plt.ylabel('Number Affected (thousands)')
plt.title('Number Indians Affected by Diseases')
plt.xticks(rotation='vertical')
plt.bar(India.columns, India.values[0], color='aquamarine')
fig.savefig('NumberIndiansAffectedByDiseases.png', bbox_inches='tight')

# %%
#Indonesia
Indonesia = country_df.loc[["Indonesia"]].sort_values(by='Indonesia', axis=1, ascending=False)
Indonesia = Indonesia.iloc[:, : 20]
Indonesia = Indonesia.drop(columns=['Population_thousands', 'All_Causes'])
#number affected by each disease
fig = plt.figure(figsize=(20,4))
plt.xlabel('Disease')
plt.ylabel('Number Affected (thousands)')
plt.title('Number Indonesians Affected by Diseases')
plt.xticks(rotation='vertical')
plt.bar(Indonesia.columns, Indonesia.values[0], color='aquamarine')
fig.savefig('NumberInonesiansAffectedByDiseases.png', bbox_inches='tight')

# %%
#Ireland
Ireland = country_df.loc[["Ireland"]].sort_values(by='Ireland', axis=1, ascending=False)
Ireland = Ireland.iloc[:, : 20]
Ireland = Ireland.drop(columns=['Population_thousands', 'All_Causes'])
#number affected by each disease
fig = plt.figure(figsize=(20,4))
plt.xlabel('Disease')
plt.ylabel('Number Affected (thousands)')
plt.title('Number Irish Affected by Diseases')
plt.xticks(rotation='vertical')
plt.bar(Ireland.columns, Ireland.values[0], color='aquamarine')
fig.savefig('NumberIrishAffectedByDiseases.png', bbox_inches='tight')

# %%
#Italy
Italy = country_df.loc[["Italy"]].sort_values(by='Italy', axis=1, ascending=False)
Italy = Italy.iloc[:, : 20]
Italy = Italy.drop(columns=['Population_thousands', 'All_Causes'])
#number affected by each disease
fig = plt.figure(figsize=(20,4))
plt.xlabel('Disease')
plt.ylabel('Number Affected (thousands)')
plt.title('Number Italians Affected by Diseases')
plt.xticks(rotation='vertical')
plt.bar(Italy.columns, Italy.values[0], color='aquamarine')
fig.savefig('NumberItaliansAffectedByDiseases.png', bbox_inches='tight')

# %%
#Japan
Japan = country_df.loc[["Japan"]].sort_values(by='Japan', axis=1, ascending=False)
Japan = Japan.iloc[:, : 20]
Japan = Japan.drop(columns=['Population_thousands', 'All_Causes'])
#number affected by each disease
fig = plt.figure(figsize=(20,4))
plt.xlabel('Disease')
plt.ylabel('Number Affected (thousands)')
plt.title('Number Japanese Affected by Diseases')
plt.xticks(rotation='vertical')
plt.bar(Japan.columns, Japan.values[0], color='aquamarine')
fig.savefig('NumberJapaneseAffectedByDiseases.png', bbox_inches='tight')

# %%
#Mexico
Mexico = country_df.loc[["Mexico"]].sort_values(by='Mexico', axis=1, ascending=False)
Mexico = Mexico.iloc[:, : 20]
Mexico = Mexico.drop(columns=['Population_thousands', 'All_Causes'])
#number affected by each disease
fig = plt.figure(figsize=(20,4))
plt.xlabel('Disease')
plt.ylabel('Number Affected (thousands)')
plt.title('Number Mexicans Affected by Diseases')
plt.xticks(rotation='vertical')
plt.bar(Mexico.columns, Mexico.values[0], color='aquamarine')
fig.savefig('NumberMexicansAffectedByDiseases.png', bbox_inches='tight')

# %%
#Philippines
Philippines = country_df.loc[["Philippines"]].sort_values(by='Philippines', axis=1, ascending=False)
Philippines = Philippines.iloc[:, : 20]
Philippines = Philippines.drop(columns=['Population_thousands', 'All_Causes'])
#number affected by each disease
fig = plt.figure(figsize=(20,4))
plt.xlabel('Disease')
plt.ylabel('Number Affected (thousands)')
plt.title('Number Philippinos Affected by Diseases')
plt.xticks(rotation='vertical')
plt.bar(Philippines.columns, Philippines.values[0], color='aquamarine')
fig.savefig('NumberPhilippinosAffectedByDiseases.png', bbox_inches='tight')

# %%
#Thailand
Thailand = country_df.loc[["Thailand"]].sort_values(by='Thailand', axis=1, ascending=False)
Thailand = Thailand.iloc[:, : 20]
Thailand = Thailand.drop(columns=['Population_thousands', 'All_Causes'])
#number affected by each disease
fig = plt.figure(figsize=(20,4))
plt.xlabel('Disease')
plt.ylabel('Number Affected (thousands)')
plt.title('Number Thai Affected by Diseases')
plt.xticks(rotation='vertical')
plt.bar(Thailand.columns, Thailand.values[0], color='aquamarine')
fig.savefig('NumberThaiAffectedByDiseases.png', bbox_inches='tight')

# %%
#Viet Nam
Viet_Nam = country_df.loc[["Viet Nam"]].sort_values(by='Viet Nam', axis=1, ascending=False)
Viet_Nam = Viet_Nam.iloc[:, : 20]
Viet_Nam = Viet_Nam.drop(columns=['Population_thousands', 'All_Causes'])
#number affected by each disease
fig = plt.figure(figsize=(20,4))
plt.xlabel('Disease')
plt.ylabel('Number Affected (thousands)')
plt.title('Number Vietnamese Affected by Diseases')
plt.xticks(rotation='vertical')
plt.bar(Viet_Nam.columns, Viet_Nam.values[0], color='aquamarine')
fig.savefig('NumberVietnameseAffectedByDiseases.png', bbox_inches='tight')

# %%
#Russia
Russia = country_df.loc[["Russian Federation"]].sort_values(by='Russian Federation', axis=1, ascending=False)
Russia = Russia.iloc[:, : 20]
Russia = Russia.drop(columns=['Population_thousands', 'All_Causes'])
#number affected by each disease
fig = plt.figure(figsize=(20,4))
plt.xlabel('Disease')
plt.ylabel('Number Affected (thousands)')
plt.title('Number Russians Affected by Diseases')
plt.xticks(rotation='vertical')
plt.bar(Russia.columns, Russia.values[0], color='aquamarine')
fig.savefig('NumberRussiansAffectedByDiseases.png', bbox_inches='tight')

# %%
#South Korea
South_Korea = country_df.loc[["Republic of Korea"]].sort_values(by='Republic of Korea', axis=1, ascending=False)
South_Korea = South_Korea.iloc[:, : 20]
South_Korea = South_Korea.drop(columns=['Population_thousands', 'All_Causes'])
#number affected by each disease
fig = plt.figure(figsize=(20,4))
plt.xlabel('Disease')
plt.ylabel('Number Affected (thousands)')
plt.title('Number South Koreans Affected by Diseases')
plt.xticks(rotation='vertical')
plt.bar(South_Korea.columns, South_Korea.values[0], color='aquamarine')
fig.savefig('NumberSouthKoreansAffectedByDiseases.png', bbox_inches='tight')

# %%
#UK
United_Kingdom = country_df.loc[["United Kingdom"]].sort_values(by='United Kingdom', axis=1, ascending=False)
United_Kingdom = United_Kingdom.iloc[:, : 20]
United_Kingdom = United_Kingdom.drop(columns=['Population_thousands', 'All_Causes'])
#number affected by each disease
fig = plt.figure(figsize=(20,4))
plt.xlabel('Disease')
plt.ylabel('Number Affected (thousands)')
plt.title('Number UK Affected by Diseases')
plt.xticks(rotation='vertical')
plt.bar(United_Kingdom.columns, United_Kingdom.values[0], color='aquamarine')
fig.savefig('NumberUKAffectedByDiseases.png', bbox_inches='tight')
